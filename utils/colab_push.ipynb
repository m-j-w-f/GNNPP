# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GNNPP
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/GNNPP

# %%
# !git config --global user.email "moritz.feik@gmail.com"
# !git config --global user.name "Moritz Feik"

# !git add .
# !git commit -m "🥳 Experiments from Colab"
# Out:
# [testing 48d1831] 🥳 Experiments from Colab
#  3 files changed, 3 insertions(+), 591 deletions(-)
#  rewrite gnn/gnn_test.ipynb (99%)
#  create mode 100644 update_git_colab.ipynb

# %%
# !git remote add neworigin https://m-j-w-f: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@github.com/m-j-w-f/GNNPP.git

# %%
# !git push neworigin testing
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 20.49 KiB | 2.56 MiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/m-j-w-f/GNNPP.git
#    810f9d1..48d1831  testing -> testing
